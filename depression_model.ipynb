# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\Projects\ScholarX\Project 1\Teen_Mental_Health_Dataset.csv")

# %%
df.head()
# Out:
#    age  gender  daily_social_media_hours platform_usage  sleep_hours  \
# 0   14    male                       7.9      Instagram          7.4
# 1   19  female                       1.9         TikTok          8.0
# 2   17  female                       1.3      Instagram          7.6
# 3   15    male                       7.4         TikTok          6.9
# 4   15  female                       4.7           Both          4.9
#
#    screen_time_before_sleep  academic_performance  physical_activity  \
# 0                       2.9                  3.01                1.5
# 1                       2.9                  3.22                0.8
# 2                       0.5                  3.92                0.0
# 3                       1.6                  3.48                0.8
# 4                       3.0                  2.37                1.4
#
#   social_interaction_level  stress_level  anxiety_level  addiction_level  \
# ...

# %%
df.isnull().sum()
# Out:
# age                         0
# gender                      0
# daily_social_media_hours    0
# platform_usage              0
# sleep_hours                 0
# screen_time_before_sleep    0
# academic_performance        0
# physical_activity           0
# social_interaction_level    0
# stress_level                0
# anxiety_level               0
# addiction_level             0
# depression_label            0
# dtype: int64

# %%
df.shape
# Out:
# (1200, 13)

# %%
col = df.columns

# %%
for i in col[0:7]:
    print(i,":",df[i].unique())
    print(":"*60)
# Out:
# age : [14 19 17 15 18 16 13]
# ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# gender : <StringArray>
# ['male', 'female']
# Length: 2, dtype: str
# ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# daily_social_media_hours : [7.9 1.9 1.3 7.4 4.7 2.5 4.  3.3 7.2 4.9 6.2 6.8 5.7 3.6 1.5 3.1 6.7 1.2
#  3.4 4.1 5.3 2.3 2.4 2.  6.6 1.6 2.7 5.  4.6 4.8 6.3 6.4 7.3 5.2 4.5 3.5
#  2.9 5.8 7.1 4.3 3.9 7.5 6.9 1.1 2.6 5.4 5.6 1.8 8.  5.1 3.2 7.7 6.5 7.8
#  6.  3.8 2.1 4.4 3.  7.  7.6 6.1 5.9 1.4 4.2 1.7 2.8 2.2 3.7 5.5 1. ]
# ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# platform_usage : <StringArray>
# ['Instagram', 'TikTok', 'Both']
# Length: 3, dtype: str
# ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# sleep_hours : [7.4 8.  7.6 6.9 4.9 4.4 6.4 4.2 5.  5.8 4.7 7.2 5.7 5.9 5.3 6.1 6.8 4.6
#  6.7 8.7 7.1 5.6 7.8 7.3 5.5 4.  8.6 7.7 8.8 4.1 4.8 5.1 6.3 8.5 4.5 6.5
#  8.2 7.  8.4 4.3 7.5 6.  5.2 9.  5.4 6.6 8.1 7.9 8.9 8.3 6.2]
# ...

# %%
for i in col[7:14]:
    print(i,":",df[i].unique())
    print(":"*60)
# Out:
# physical_activity : [1.5 0.8 0.  1.4 0.6 0.7 1.3 0.9 1.1 1.2 1.7 0.3 0.5 1.9 0.4 0.1 1.6 1.8
#  0.2 1.  2. ]
# ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# social_interaction_level : <StringArray>
# ['low', 'high', 'medium']
# Length: 3, dtype: str
# ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# stress_level : [ 2  8  1  3  6  5  4 10  9  7]
# ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# anxiety_level : [ 2  1  4  7  5 10  8  9  6  3]
# ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# addiction_level : [ 1 10  2  9  7  5  4  8  6  3]
# ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# depression_label : [0 1]
# ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::

# %%
df["platform_usage"] = df["platform_usage"].map({"Instagram":0,"TikTok":1,"Both":2},inplace=True)
df["gender"] = df["gender"].map({"male":1,"female":0},inplace=True)
df["social_interaction_level"] = df["social_interaction_level"].map({"low":0,"medium":1,"high":2},inplace=True)

# %%
df.head()
# Out:
#    age  gender  daily_social_media_hours  platform_usage  sleep_hours  \
# 0   14       1                       7.9               0          7.4
# 1   19       0                       1.9               1          8.0
# 2   17       0                       1.3               0          7.6
# 3   15       1                       7.4               1          6.9
# 4   15       0                       4.7               2          4.9
#
#    screen_time_before_sleep  academic_performance  physical_activity  \
# 0                       2.9                  3.01                1.5
# 1                       2.9                  3.22                0.8
# 2                       0.5                  3.92                0.0
# 3                       1.6                  3.48                0.8
# 4                       3.0                  2.37                1.4
#
#    social_interaction_level  stress_level  anxiety_level  addiction_level  \
# ...

# %%
sns.scatterplot(x="daily_social_media_hours",y="academic_performance",hue="age",data=df)
plt.plot()
# Out:
# []

# %%
sns.barplot(x="age",y="daily_social_media_hours",data=df)
plt.plot()
# Out:
# []

# %%
sns.barplot(x="age",y="stress_level",data=df)
plt.plot()
# Out:
# []

# %%
x = df.drop("depression_label",axis=1)
y = df["depression_label"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
x_train_scaled = scalar.fit_transform(x_train)
x_test_scaled = scalar.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
pred = model.predict(x_test_scaled)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

mse = mean_squared_error(y_test, pred)
print("Mean Squared Error:",mse)
# Out:
# Mean Squared Error: 0.0125

# %%
r2_score = r2_score(y_test, pred)
print("R^2 Score:",r2_score)
# Out:
# R^2 Score: 0.4871794871794871

# %%
mae = mean_absolute_error(y_test, pred)
print("Mean Absolute Error:",mae)
# Out:
# Mean Absolute Error: 0.0125

# %%
rmse = np.sqrt(mse)
print("Root Mean Squared Error:",rmse)
# Out:
# Root Mean Squared Error: 0.11180339887498948

# %%
import joblib
joblib.dump(model, "depression_model.pkl")
# Out:
# ['depression_model.pkl']

# %%
for i in df.columns:
    print(dtype(i))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 2
#       1 for i in df.columns:
# ----> 2     print(i.dtype)
#
# AttributeError: 'str' object has no attribute 'dtype'
